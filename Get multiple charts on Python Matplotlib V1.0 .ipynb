# %%
#引用套件並縮寫為 pd 
#Numpy是Python中科學計算的核心資源庫。Numpy提供了高效能的多維陣列物件，還有用於處理這些陣列的工具。
#Matplotlib 資料視覺化
#Created by Tommas Huang  Date: 2019-11-30
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Pandas 讀取資料來源內容
df = pd.read_csv('/Users/TommasHuang/Downloads/TimeSeriesPythonPandaPlot/Data.csv')

# %%
#您可以使用pivot_table：
#然後是DataFrame.plot
df = df.pivot_table(index='Date', columns='Region', values='Sales', aggfunc='sum')
print (df)
df.plot()
# Out:
# Region      Europe  USA
# Date
# 01/01/2016       2    1
# 01/02/2016       4    3
